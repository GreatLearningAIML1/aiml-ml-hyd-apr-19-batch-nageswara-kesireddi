# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Read the data set and replace dashes with 0 to make sure you can perform arithmetic operations on the data

# %%
dsTeams=pd.read_csv("C:/Users/Nageswar/AIML/Labs/Residency1/Assignment/Laliga.csv",skiprows=1)
dsTeams=dsTeams.replace("-",0)

dsTeams.GoalsFor=dsTeams.GoalsFor.astype('int64')
dsTeams.GoalsAgainst=dsTeams.GoalsAgainst.astype('int64')
dsTeams.Points=dsTeams.Points.astype('int64')
dsTeams.GamesPlayed=dsTeams.GamesPlayed.astype('int64')
dsTeams.GamesWon=dsTeams.GamesWon.astype('int64')

print(dsTeams)
# Out:
#     Pos                 Team  Seasons  Points  GamesPlayed  GamesWon  \
# 0     1          Real Madrid       86    4385         2762      1647
# 1     2            Barcelona       86    4262         2762      1581
# 2     3      Atletico Madrid       80    3442         2614      1241
# 3     4             Valencia       82    3386         2664      1187
# 4     5      Athletic Bilbao       86    3368         2762      1209
# 5     6              Sevilla       73    2819         2408       990
# 6     7             Espanyol       82    2792         2626       948
# 7     8        Real Sociedad       70    2573         2302       864
# 8     9             Zaragoza       58    2109         1986       698
# 9    10           Real Betis       51    1884         1728       606
# 10   11  Deportivo La Coruna       45    1814         1530       563
# 11   12           Celta Vigo       51    1789         1698       586
# 12   13           Valladolid       42    1471         1466       463
# ...

# %%
#Print all the teams which have started playing between 1930-1980
## First I split the column "Debut in to two columns so that I can perform the arithmatic operations"
## and stored the starting year in the "DebutStart" field

# %%
dsTeams[['DebutStart','DebutEnd']]=dsTeams["Debut"].str.split("-",expand=True)

dsTeams.DebutStart=dsTeams.DebutStart.astype('int64')

print (dsTeams[(dsTeams["DebutStart"]>=1930 ) & (dsTeams["DebutStart"]<=1980 )])
# Out:
#     Pos                 Team  Seasons  Points  GamesPlayed  GamesWon  \
# 3     4             Valencia       82    3386         2664      1187
# 5     6              Sevilla       73    2819         2408       990
# 8     9             Zaragoza       58    2109         1986       698
# 9    10           Real Betis       51    1884         1728       606
# 10   11  Deportivo La Coruna       45    1814         1530       563
# 11   12           Celta Vigo       51    1789         1698       586
# 12   13           Valladolid       42    1471         1466       463
# 14   15       Sporting Gijon       43    1389         1458       471
# 15   16              Osasuna       37    1351         1318       426
# 16   17               Malaga       36    1314         1255       390
# 17   18               Oviedo       38    1174         1192       408
# 18   19             Mallorca       27    1148          988       333
# 19   20           Las Palmas       33    1020         1096       367
# ...

# %%
#Print the list of teams which came Top 5 in terms of points

# %%
print (dsTeams.sort_values(by="Points",ascending=False).head(5))
# Out:
#    Pos             Team  Seasons  Points  GamesPlayed  GamesWon GamesDrawn  \
# 0    1      Real Madrid       86    4385         2762      1647        552
# 1    2        Barcelona       86    4262         2762      1581        573
# 2    3  Atletico Madrid       80    3442         2614      1241        598
# 3    4         Valencia       82    3386         2664      1187        616
# 4    5  Athletic Bilbao       86    3368         2762      1209        633
#
#   GamesLost  GoalsFor  GoalsAgainst  ... Third Fourth Fifth Sixth   T  \
# 0       563      5947          3140  ...     8      8     3     4  79
# 1       608      5900          3114  ...    12     12     4     6  83
# 2       775      4534          3309  ...    16      9     7     6  56
# 3       861      4398          3469  ...    10     11    10     7  50
# 4       920      4631          3700  ...    10      5     8    10  49
#
#      Debut Since/LastApp BestPosition DebutStart  DebutEnd
# ...

# %%
#Write a function with name “Goal_diff_count” which should return all the teams with their Goal Differences. Using the same function, find the team which has maximum and minimum goal difference

# %%
def NGoal_diff_count(df):
    df.insert(22, "Goal_diff_count",df["GoalsFor"]-df["GoalsAgainst"])
    #df.loc[["Team"],[df["Goal_diff_count"].idxmax()]]
    MaxDiff=df.loc[[df["Goal_diff_count"].idxmax()]]  #1  #df.loc[df["Goal_diff_count"].idxmax()]
    MinDiff=df.loc[[df["Goal_diff_count"].idxmin()]]
    return (df,MaxDiff,MinDiff)

# %%
x,y,z=NGoal_diff_count(dsTeams)

# %%
#printing the Data Set with Goal Differences

# %%
print ("New Data Set with Goal Differences")
print(x)
# Out:
# New Data Set with Goal Differences
#     Pos                 Team  Seasons  Points  GamesPlayed  GamesWon  \
# 0     1          Real Madrid       86    4385         2762      1647
# 1     2            Barcelona       86    4262         2762      1581
# 2     3      Atletico Madrid       80    3442         2614      1241
# 3     4             Valencia       82    3386         2664      1187
# 4     5      Athletic Bilbao       86    3368         2762      1209
# 5     6              Sevilla       73    2819         2408       990
# 6     7             Espanyol       82    2792         2626       948
# 7     8        Real Sociedad       70    2573         2302       864
# 8     9             Zaragoza       58    2109         1986       698
# 9    10           Real Betis       51    1884         1728       606
# 10   11  Deportivo La Coruna       45    1814         1530       563
# 11   12           Celta Vigo       51    1789         1698       586
# ...

# %%
#Printing the Team with Max Goal Differences

# %%
print("Team with Max Goal Differences")
print(y)
# Out:
# Team with Max Goal Differences
#    Pos         Team  Seasons  Points  GamesPlayed  GamesWon GamesDrawn  \
# 0    1  Real Madrid       86    4385         2762      1647        552
#
#   GamesLost  GoalsFor  GoalsAgainst  ... Fourth Fifth Sixth   T Debut  \
# 0       563      5947          3140  ...      8     3     4  79  1929
#
#   Since/LastApp BestPosition DebutStart DebutEnd  Goal_diff_count
# 0          1929            1       1929     None             2807
#
# [1 rows x 23 columns]

# %%
#Printing the Team wiht Min Goal differences

# %%
print("Team with Min Goal Differences")
print(z)
# Out:
# Team with Min Goal Differences
#     Pos              Team  Seasons  Points  GamesPlayed  GamesWon GamesDrawn  \
# 13   14  Racing Santander       44    1416         1428       453        336
#
#    GamesLost  GoalsFor  GoalsAgainst  ... Fourth Fifth Sixth  T Debut  \
# 13       639      1843          2368  ...      2     0     1  5  1929
#
#    Since/LastApp BestPosition DebutStart DebutEnd  Goal_diff_count
# 13       2011-12            2       1929     None             -525
#
# [1 rows x 23 columns]

# %%
#Create a new column with name “Winning Percent” and append it to the data set

# %%
dsTeams.insert(23,"Winning Percent",(dsTeams["GamesWon"]/dsTeams["GamesPlayed"])*100)

# %%
#replacing numerical errors with Zeros

# %%
dsTeams["Winning Percent"]=pd.to_numeric(dsTeams["Winning Percent"],errors='coerce').fillna(0)

# %%
#top 5 teams with highest winning percentage

# %%
print(dsTeams.sort_values(by="Winning Percent",ascending=False).head(5))
# Out:
#    Pos             Team  Seasons  Points  GamesPlayed  GamesWon GamesDrawn  \
# 0    1      Real Madrid       86    4385         2762      1647        552
# 1    2        Barcelona       86    4262         2762      1581        573
# 2    3  Atletico Madrid       80    3442         2614      1241        598
# 3    4         Valencia       82    3386         2664      1187        616
# 4    5  Athletic Bilbao       86    3368         2762      1209        633
#
#   GamesLost  GoalsFor  GoalsAgainst  ... Fifth Sixth   T    Debut  \
# 0       563      5947          3140  ...     3     4  79     1929
# 1       608      5900          3114  ...     4     6  83     1929
# 2       775      4534          3309  ...     7     6  56     1929
# 3       861      4398          3469  ...    10     7  50  1931-32
# 4       920      4631          3700  ...     8    10  49     1929
#
#   Since/LastApp BestPosition DebutStart DebutEnd Goal_diff_count  \
# ...

# %%
#Group teams based on their “Best position” and print the sum of their points for all positions

# %%
print(dsTeams.groupby("BestPosition")["Points"].sum())
# Out:
# BestPosition
# 1     27933
# 2      6904
# 3      5221
# 4      6563
# 5      1884
# 6      2113
# 7      1186
# 8      1134
# 9        96
# 10      450
# 11      445
# 12      511
# 14       71
# 15       14
# 16       81
# 17      266
# 19       81
# 20       34
# Name: Points, dtype: int64
